# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_20396\1135392035.py in <module>
#       6
#       7 # Import API key
# ----> 8 from config import g_key
#       9
#      10 # Configure gmaps API key
#
# ModuleNotFoundError: No module named 'config'

# %%
g_key="AIzaSyApIcpVRYTrqHojvsLGl_l2QHG0CeVdC48"

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("D:/Data_Visualization_and_Analytics_Boot_Camp/06_Challenge/Weather_Database/WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Kununurra      AU -15.7667  128.7333     87.78        20
# 1        1         Kampot      KH  10.6167  104.1833     86.05        57
# 2        2  San Cristobal      VE   7.7669  -72.2250     68.18        98
# 3        3       San Jose      US  37.3394 -121.8950     90.68        33
# 4        4        Cozumel      MX  20.5083  -86.9458     75.94        94
#
#    Cloudiness  Wind Speed Current Description
# 0           4       13.80           clear sky
# 1          86        6.42     overcast clouds
# 2          54        3.15       broken clouds
# 3           0       11.50           clear sky
# 4          64       10.69       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you prefer? "))
max_temp = float(input("What is the maximum temperature you prefer? "))
# Out:
# What is the minimum temperature you prefer? 40
# What is the maximum temperature you prefer? 100

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head()
# Out:
#    City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Kununurra      AU -15.7667  128.7333     87.78        20
# 1        1         Kampot      KH  10.6167  104.1833     86.05        57
# 2        2  San Cristobal      VE   7.7669  -72.2250     68.18        98
# 3        3       San Jose      US  37.3394 -121.8950     90.68        33
# 4        4        Cozumel      MX  20.5083  -86.9458     75.94        94
#
#    Cloudiness  Wind Speed Current Description
# 0           4       13.80           clear sky
# 1          86        6.42     overcast clouds
# 2          54        3.15       broken clouds
# 3           0       11.50           clear sky
# 4          64       10.69       broken clouds

# %%
# 4a. Determine if there are any empty rows.
city_data_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                5
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
no_empty_df = city_data_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = no_empty_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 0      Kununurra      AU     87.78           clear sky -15.7667  128.7333
# 1         Kampot      KH     86.05     overcast clouds  10.6167  104.1833
# 2  San Cristobal      VE     68.18       broken clouds   7.7669  -72.2250
# 3       San Jose      US     90.68           clear sky  37.3394 -121.8950
# 4        Cozumel      MX     75.94       broken clouds  20.5083  -86.9458
#
#   Hotel Name
# 0
# 1
# 2
# 3
# 4

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

counter = 0

# 6b. Iterate through the hotel DataFrame.
    # 6c. Get latitude and longitude from DataFrame
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        counter += 1
        print("No Hotel found. ", counter)
# Out:
# No Hotel found.  1
# No Hotel found.  2
# No Hotel found.  3
# No Hotel found.  4
# No Hotel found.  5
# No Hotel found.  6
# No Hotel found.  7
# No Hotel found.  8
# No Hotel found.  9
# No Hotel found.  10
# No Hotel found.  11
# No Hotel found.  12
# No Hotel found.  13
# No Hotel found.  14
# No Hotel found.  15
# No Hotel found.  16
# No Hotel found.  17
# No Hotel found.  18
# No Hotel found.  19
# No Hotel found.  20
# No Hotel found.  21
# No Hotel found.  22
# No Hotel found.  23
# No Hotel found.  24
# No Hotel found.  25
# No Hotel found.  26
# No Hotel found.  27
# No Hotel found.  28
# No Hotel found.  29
# No Hotel found.  30
# No Hotel found.  31
# No Hotel found.  32
# No Hotel found.  33
# No Hotel found.  34
# No Hotel found.  35
# No Hotel found.  36
# No Hotel found.  37
# No Hotel found.  38
# No Hotel found.  39
# No Hotel found.  40
# No Hotel found.  41
# No Hotel found.  42
# No Hotel found.  43
# No Hotel found.  44
# No Hotel found.  45
# ...

# %%
import numpy as np
# 7. Drop the rows where there is no Hotel Name.
hotel_df["Hotel Name"].replace("", np.nan, inplace=True)
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
# Empty DataFrame
# Columns: [City, Country, Max Temp, Current Description, Lat, Lng, Hotel Name]
# Index: []

# %%
# 8a. Create the output File (CSV)
vacation_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(vacation_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
figure = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
figure.add_layer(marker_layer)

# 11b. Display the figure
figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
