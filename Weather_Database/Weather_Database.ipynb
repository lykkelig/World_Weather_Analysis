# %%
# Import the dependencies.
import sys
import requests
import pandas as pd
import numpy as np
from citipy import citipy
import matplotlib.pyplot as plt

# %%
# Import the API key.
from config import api_key

# %%
# Randomly generate a set of 2,000 latitude and longitude coordinates.
latitude = np.random.uniform(low=-90.000, high=90.000, size=2000)
longitude = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(latitude, longitude)
lat_lng

# %%
# Place the corrdinates in a list
lat_long_coordinates = list(lat_lng)

# %%
# Initialize a list 
cities = []
# Search for the nearest city closest to the generated latitude and longitude combination.
for lat_lng_coord in lat_long_coordinates:
    city = citipy.nearest_city(lat_lng_coord[0], lat_lng_coord[1]).city_name
    if city not in cities:   # Check for duplicates
        cities.append(city)

len(cities)
# Out:
# 743

# %%
sys.path.insert(0, '../')
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dcc05e6a0e2610073debe29ab9dc37e3

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Weather Data Complete        ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kununurra
# {'coord': {'lon': 128.7333, 'lat': -15.7667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 87.78, 'feels_like': 84.33, 'temp_min': 87.78, 'temp_max': 87.78, 'pressure': 1015, 'humidity': 20}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 130}, 'clouds': {'all': 4}, 'dt': 1655872889, 'sys': {'type': 1, 'id': 9587, 'country': 'AU', 'sunrise': 1655848275, 'sunset': 1655888555}, 'timezone': 28800, 'id': 2068110, 'name': 'Kununurra', 'cod': 200}
# Processing Record 2 of Set 1 | kampot
# {'coord': {'lon': 104.1833, 'lat': 10.6167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 86.05, 'feels_like': 90.16, 'temp_min': 86.05, 'temp_max': 86.05, 'pressure': 1009, 'humidity': 57, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 6.42, 'deg': 220, 'gust': 7.78}, 'clouds': {'all': 86}, 'dt': 1655872890, 'sys': {'type': 1, 'id': 9312, 'country': 'KH', 'sunrise': 1655851367, 'sunset': 1655897249}, 'timezone': 25200, 'id': 1831112, 'name': 'Kampot', 'cod': 200}
# Processing Record 3 of Set 1 | san cristobal
# {'coord': {'lon': -72.225, 'lat': 7.7669}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 68.18, 'feels_like': 69.3, 'temp_min': 68.18, 'temp_max': 68.18, 'pressure': 1015, 'humidity': 98, 'sea_level': 1015, 'grnd_level': 913}, 'visibility': 10000, 'wind': {'speed': 3.15, 'deg': 108, 'gust': 5.73}, 'clouds': {'all': 54}, 'dt': 1655872890, 'sys': {'type': 1, 'id': 8587, 'country': 'VE', 'sunrise': 1655894019, 'sunset': 1655939285}, 'timezone': -14400, 'id': 3628473, 'name': 'San Cristobal', 'cod': 200}
# Processing Record 4 of Set 1 | san jose
# {'coord': {'lon': -121.895, 'lat': 37.3394}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.4, 'feels_like': 79.65, 'temp_min': 59.99, 'temp_max': 90.68, 'pressure': 1010, 'humidity': 33}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 350, 'gust': 23.02}, 'clouds': {'all': 0}, 'dt': 1655872681, 'sys': {'type': 1, 'id': 5845, 'country': 'US', 'sunrise': 1655815636, 'sunset': 1655868688}, 'timezone': -25200, 'id': 5392171, 'name': 'San Jose', 'cod': 200}
# Processing Record 5 of Set 1 | cozumel
# {'coord': {'lon': -86.9458, 'lat': 20.5083}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.94, 'feels_like': 77.65, 'temp_min': 75.94, 'temp_max': 75.94, 'pressure': 1016, 'humidity': 94, 'sea_level': 1016, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 10.69, 'deg': 75, 'gust': 17.76}, 'clouds': {'all': 64}, 'dt': 1655872721, 'sys': {'type': 2, 'id': 2042794, 'country': 'MX', 'sunrise': 1655809698, 'sunset': 1655857849}, 'timezone': -18000, 'id': 3530103, 'name': 'San Miguel de Cozumel', 'cod': 200}
# Processing Record 6 of Set 1 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 46.47, 'feels_like': 46.47, 'temp_min': 46.47, 'temp_max': 46.47, 'pressure': 1026, 'humidity': 87, 'sea_level': 1026, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 1.19, 'deg': 24, 'gust': 1.19}, 'clouds': {'all': 1}, 'dt': 1655872890, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1655843282, 'sunset': 1655874283}, 'timezone': 43200, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 7 of Set 1 | butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.94, 'feels_like': 88.27, 'temp_min': 82.94, 'temp_max': 82.94, 'pressure': 1008, 'humidity': 70, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 12.88, 'deg': 119, 'gust': 13.82}, 'clouds': {'all': 68}, 'dt': 1655872891, 'sys': {'country': 'KI', 'sunrise': 1655835703, 'sunset': 1655879977}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 8 of Set 1 | port alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 65.03, 'feels_like': 65.08, 'temp_min': 65.03, 'temp_max': 65.03, 'pressure': 1023, 'humidity': 82, 'sea_level': 1023, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 18.9, 'deg': 53, 'gust': 33.24}, 'clouds': {'all': 100}, 'dt': 1655872891, 'sys': {'country': 'ZA', 'sunrise': 1655875006, 'sunset': 1655910716}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 9 of Set 1 | atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77.65, 'feels_like': 78.93, 'temp_min': 77.65, 'temp_max': 77.65, 'pressure': 1013, 'humidity': 81, 'sea_level': 1013, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 24.54, 'deg': 106, 'gust': 26.82}, 'rain': {'1h': 0.19}, 'clouds': {'all': 14}, 'dt': 1655872891, 'sys': {'country': 'PF', 'sunrise': 1655825486, 'sunset': 1655867066}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 10 of Set 1 | sorland
# {'coord': {'lon': 12.6934, 'lat': 67.667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 46.26, 'feels_like': 45.36, 'temp_min': 46.26, 'temp_max': 46.26, 'pressure': 1008, 'humidity': 63, 'sea_level': 1008, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 221, 'gust': 3.44}, 'clouds': {'all': 100}, 'dt': 1655872892, 'sys': {'type': 1, 'id': 1661, 'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 7200, 'id': 3137469, 'name': 'Sørland', 'cod': 200}
# Processing Record 11 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 73.31, 'feels_like': 73.4, 'temp_min': 73.31, 'temp_max': 73.31, 'pressure': 1021, 'humidity': 65, 'sea_level': 1021, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 8.41, 'deg': 17, 'gust': 8.55}, 'clouds': {'all': 36}, 'dt': 1655872892, 'sys': {'country': 'PF', 'sunrise': 1655826021, 'sunset': 1655864580}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 12 of Set 1 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.94, 'feels_like': 55.74, 'temp_min': 55.94, 'temp_max': 55.94, 'pressure': 1022, 'humidity': 96, 'sea_level': 1022, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 4.56, 'deg': 62, 'gust': 5.48}, 'clouds': {'all': 100}, 'dt': 1655872892, 'sys': {'country': 'ZA', 'sunrise': 1655876795, 'sunset': 1655912215}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 13 of Set 1 | methoni
# {'coord': {'lon': 21.7049, 'lat': 36.8197}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.46, 'feels_like': 71.49, 'temp_min': 71.46, 'temp_max': 71.46, 'pressure': 1011, 'humidity': 68, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 11.03, 'deg': 335, 'gust': 14.34}, 'clouds': {'all': 0}, 'dt': 1655872893, 'sys': {'type': 1, 'id': 6621, 'country': 'GR', 'sunrise': 1655867672, 'sunset': 1655920539}, 'timezone': 10800, 'id': 257122, 'name': 'Methóni', 'cod': 200}
# Processing Record 14 of Set 1 | luderitz
# {'coord': {'lon': 15.1594, 'lat': -26.6481}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 52.68, 'feels_like': 51.13, 'temp_min': 52.68, 'temp_max': 52.68, 'pressure': 1020, 'humidity': 74, 'sea_level': 1020, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 4.76, 'deg': 127, 'gust': 6.24}, 'clouds': {'all': 1}, 'dt': 1655872893, 'sys': {'country': 'NA', 'sunrise': 1655876844, 'sunset': 1655914510}, 'timezone': 7200, 'id': 3355672, 'name': 'Lüderitz', 'cod': 200}
# Processing Record 15 of Set 1 | zhezkazgan
# {'coord': {'lon': 67.7144, 'lat': 47.8043}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.58, 'feels_like': 79.05, 'temp_min': 80.58, 'temp_max': 80.58, 'pressure': 1005, 'humidity': 22}, 'visibility': 10000, 'wind': {'speed': 8.95, 'deg': 340}, 'clouds': {'all': 0}, 'dt': 1655872893, 'sys': {'type': 1, 'id': 8826, 'country': 'KZ', 'sunrise': 1655854234, 'sunset': 1655911889}, 'timezone': 21600, 'id': 1516589, 'name': 'Zhezkazgan', 'cod': 200}
# Processing Record 16 of Set 1 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 55.49, 'feels_like': 55.02, 'temp_min': 54.01, 'temp_max': 57.11, 'pressure': 1020, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 200}, 'clouds': {'all': 0}, 'dt': 1655872628, 'sys': {'type': 2, 'id': 2073005, 'country': 'ZA', 'sunrise': 1655877089, 'sunset': 1655912697}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 17 of Set 1 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 37.06, 'feels_like': 25.14, 'temp_min': 37.06, 'temp_max': 37.06, 'pressure': 1016, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 26.46, 'deg': 250}, 'clouds': {'all': 20}, 'dt': 1655872635, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1655902739, 'sunset': 1655928681}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 19 of Set 1 | new norfolk
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 50.43, 'temp_min': 50.9, 'temp_max': 56.88, 'pressure': 1017, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 1.52, 'deg': 311, 'gust': 3.78}, 'clouds': {'all': 39}, 'dt': 1655872894, 'sys': {'type': 2, 'id': 2031307, 'country': 'AU', 'sunrise': 1655847772, 'sunset': 1655880261}, 'timezone': 36000, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# Processing Record 20 of Set 1 | ust-kamchatsk
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 21 of Set 1 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.79, 'feels_like': 57.07, 'temp_min': 57.79, 'temp_max': 57.79, 'pressure': 1021, 'humidity': 81, 'sea_level': 1021, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 7.29, 'deg': 63, 'gust': 8.19}, 'clouds': {'all': 100}, 'dt': 1655872895, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1655876971, 'sunset': 1655912426}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 22 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 66.9, 'feels_like': 66.31, 'temp_min': 66.9, 'temp_max': 66.9, 'pressure': 1019, 'humidity': 64, 'sea_level': 1019, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 15.64, 'deg': 303, 'gust': 19.42}, 'clouds': {'all': 50}, 'dt': 1655872895, 'sys': {'country': 'AU', 'sunrise': 1655853786, 'sunset': 1655889478}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 23 of Set 1 | plettenberg bay
# {'coord': {'lon': 23.3716, 'lat': -34.0527}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.56, 'feels_like': 58.41, 'temp_min': 59.56, 'temp_max': 59.56, 'pressure': 1022, 'humidity': 68, 'sea_level': 1022, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 1.36, 'deg': 323, 'gust': 2.28}, 'clouds': {'all': 99}, 'dt': 1655872896, 'sys': {'country': 'ZA', 'sunrise': 1655875921, 'sunset': 1655911490}, 'timezone': 7200, 'id': 964712, 'name': 'Plettenberg Bay', 'cod': 200}
# Processing Record 24 of Set 1 | hihifo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 25 of Set 1 | jalu
# {'coord': {'lon': 21.5482, 'lat': 29.0331}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 77.59, 'feels_like': 76.75, 'temp_min': 77.59, 'temp_max': 77.59, 'pressure': 1012, 'humidity': 36, 'sea_level': 1012, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 6.33, 'deg': 82, 'gust': 9.15}, 'clouds': {'all': 0}, 'dt': 1655872896, 'sys': {'country': 'LY', 'sunrise': 1655868945, 'sunset': 1655919342}, 'timezone': 7200, 'id': 86049, 'name': 'Jalu', 'cod': 200}
# Processing Record 26 of Set 1 | yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 64.92, 'feels_like': 63.55, 'temp_min': 64.56, 'temp_max': 64.92, 'pressure': 1011, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 240}, 'clouds': {'all': 40}, 'dt': 1655872896, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1655804367, 'sunset': 1655876337}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 27 of Set 1 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.2, 'feels_like': 59.14, 'temp_min': 57.88, 'temp_max': 61.3, 'pressure': 1016, 'humidity': 92}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 104, 'gust': 8.99}, 'clouds': {'all': 100}, 'dt': 1655872836, 'sys': {'type': 2, 'id': 19530, 'country': 'US', 'sunrise': 1655889508, 'sunset': 1655944631}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 28 of Set 1 | puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 69.55, 'feels_like': 70.66, 'temp_min': 69.55, 'temp_max': 69.55, 'pressure': 1014, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 150, 'gust': 3}, 'clouds': {'all': 42}, 'dt': 1655872897, 'sys': {'type': 2, 'id': 2005652, 'country': 'EC', 'sunrise': 1655812851, 'sunset': 1655856331}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 29 of Set 1 | kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.11, 'feels_like': 69.8, 'temp_min': 71.11, 'temp_max': 71.11, 'pressure': 1023, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 280}, 'clouds': {'all': 0}, 'dt': 1655872897, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1655816876, 'sunset': 1655882097}, 'timezone': -28800, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 30 of Set 1 | obluche
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 31 of Set 1 | provideniya
# {'coord': {'lon': -173.3, 'lat': 64.3833}, 'weather': [{'id': 301, 'main': 'Drizzle', 'description': 'drizzle', 'icon': '09n'}, {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 41.11, 'feels_like': 33.89, 'temp_min': 41.11, 'temp_max': 41.36, 'pressure': 1014, 'humidity': 100}, 'visibility': 500, 'wind': {'speed': 13, 'deg': 180, 'gust': 0}, 'clouds': {'all': 100}, 'dt': 1655872898, 'sys': {'type': 1, 'id': 8875, 'country': 'RU', 'sunrise': 1655902479, 'sunset': 1655979348}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# Processing Record 32 of Set 1 | kapaa
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 75.72, 'feels_like': 76.98, 'temp_min': 75.47, 'temp_max': 82.38, 'pressure': 1018, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1655872898, 'sys': {'type': 2, 'id': 2001562, 'country': 'US', 'sunrise': 1655826876, 'sunset': 1655875414}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 33 of Set 1 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 45.18, 'feels_like': 41.41, 'temp_min': 42.82, 'temp_max': 46.09, 'pressure': 1025, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 190}, 'clouds': {'all': 0}, 'dt': 1655872748, 'sys': {'type': 2, 'id': 268283, 'country': 'AR', 'sunrise': 1655895991, 'sunset': 1655930271}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 34 of Set 1 | katsuura
# {'coord': {'lon': 140.3, 'lat': 35.1333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 73.78, 'feels_like': 74.89, 'temp_min': 73.78, 'temp_max': 73.78, 'pressure': 1010, 'humidity': 86, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 5.5, 'deg': 145, 'gust': 6.04}, 'clouds': {'all': 90}, 'dt': 1655872898, 'sys': {'country': 'JP', 'sunrise': 1655839496, 'sunset': 1655891782}, 'timezone': 32400, 'id': 2112309, 'name': 'Katsuura', 'cod': 200}
# Processing Record 35 of Set 1 | hamilton
# {'coord': {'lon': -84.5333, 'lat': 39.1834}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.5, 'feels_like': 73.02, 'temp_min': 66.49, 'temp_max': 76.05, 'pressure': 1018, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1655872874, 'sys': {'type': 2, 'id': 2005257, 'country': 'US', 'sunrise': 1655892740, 'sunset': 1655946473}, 'timezone': -14400, 'id': 4513583, 'name': 'Hamilton', 'cod': 200}
# Processing Record 36 of Set 1 | teguise
# {'coord': {'lon': -13.564, 'lat': 29.0605}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.82, 'feels_like': 62.19, 'temp_min': 62.82, 'temp_max': 62.82, 'pressure': 1017, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 350}, 'clouds': {'all': 0}, 'dt': 1655872899, 'sys': {'type': 1, 'id': 2379, 'country': 'ES', 'sunrise': 1655877369, 'sunset': 1655927773}, 'timezone': 3600, 'id': 2510573, 'name': 'Teguise', 'cod': 200}
# Processing Record 37 of Set 1 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.36, 'feels_like': 53.13, 'temp_min': 55.36, 'temp_max': 55.36, 'pressure': 1009, 'humidity': 54, 'sea_level': 1009, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 10.22, 'deg': 43, 'gust': 9.78}, 'clouds': {'all': 99}, 'dt': 1655872899, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 38 of Set 1 | kayes
# {'coord': {'lon': -11, 'lat': 14}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 84.58, 'feels_like': 87.12, 'temp_min': 84.58, 'temp_max': 84.58, 'pressure': 1011, 'humidity': 55, 'sea_level': 1011, 'grnd_level': 988}, 'visibility': 10000, 'wind': {'speed': 2.35, 'deg': 131, 'gust': 2.3}, 'clouds': {'all': 61}, 'dt': 1655872900, 'sys': {'country': 'ML', 'sunrise': 1655878641, 'sunset': 1655925270}, 'timezone': 0, 'id': 2455517, 'name': 'Kayes', 'cod': 200}
# Processing Record 39 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 33.91, 'feels_like': 21.99, 'temp_min': 33.12, 'temp_max': 33.91, 'pressure': 1020, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 270}, 'clouds': {'all': 0}, 'dt': 1655872900, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1655902780, 'sunset': 1655929895}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 40 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 78.96, 'feels_like': 78.96, 'temp_min': 78.96, 'temp_max': 78.96, 'pressure': 1013, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 240}, 'clouds': {'all': 20}, 'dt': 1655872900, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1655921856, 'sunset': 1655960882}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 41 of Set 1 | longmont
# {'coord': {'lon': -105.1019, 'lat': 40.1672}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.89, 'feels_like': 60.57, 'temp_min': 58.6, 'temp_max': 66.67, 'pressure': 986, 'humidity': 36}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 150}, 'clouds': {'all': 0}, 'dt': 1655872885, 'sys': {'type': 2, 'id': 2043479, 'country': 'US', 'sunrise': 1655811072, 'sunset': 1655865190}, 'timezone': -21600, 'id': 5579276, 'name': 'Longmont', 'cod': 200}
# Processing Record 42 of Set 1 | sretensk
# {'coord': {'lon': 117.7093, 'lat': 52.2453}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 74.84, 'feels_like': 74.05, 'temp_min': 74.84, 'temp_max': 74.84, 'pressure': 998, 'humidity': 43, 'sea_level': 998, 'grnd_level': 947}, 'visibility': 10000, 'wind': {'speed': 7.49, 'deg': 291, 'gust': 10.54}, 'clouds': {'all': 21}, 'dt': 1655872901, 'sys': {'country': 'RU', 'sunrise': 1655840858, 'sunset': 1655901265}, 'timezone': 32400, 'id': 2016110, 'name': 'Sretensk', 'cod': 200}
# Processing Record 43 of Set 1 | victoria
# {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 87.13, 'feels_like': 99.73, 'temp_min': 81.95, 'temp_max': 92.17, 'pressure': 1010, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 10, 'deg': 210}, 'clouds': {'all': 97}, 'dt': 1655872901, 'sys': {'type': 2, 'id': 265999, 'country': 'HK', 'sunrise': 1655847618, 'sunset': 1655896209}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# Processing Record 44 of Set 1 | humberto de campos
# {'coord': {'lon': -43.4611, 'lat': -2.5983}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.56, 'feels_like': 74.95, 'temp_min': 73.56, 'temp_max': 73.56, 'pressure': 1012, 'humidity': 92, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 0.54, 'deg': 331, 'gust': 1.74}, 'clouds': {'all': 98}, 'dt': 1655872901, 'sys': {'country': 'BR', 'sunrise': 1655888201, 'sunset': 1655931294}, 'timezone': -10800, 'id': 3398428, 'name': 'Humberto de Campos', 'cod': 200}
# Processing Record 45 of Set 1 | coracora
# {'coord': {'lon': -73.7833, 'lat': -15.0333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 43.77, 'feels_like': 42.08, 'temp_min': 43.77, 'temp_max': 43.77, 'pressure': 1019, 'humidity': 42, 'sea_level': 1019, 'grnd_level': 695}, 'visibility': 10000, 'wind': {'speed': 3.56, 'deg': 10, 'gust': 3.69}, 'clouds': {'all': 27}, 'dt': 1655872902, 'sys': {'country': 'PE', 'sunrise': 1655810392, 'sunset': 1655850835}, 'timezone': -18000, 'id': 3942259, 'name': 'Coracora', 'cod': 200}
# Processing Record 46 of Set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 47 of Set 1 | halalo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 48 of Set 1 | airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 71.37, 'feels_like': 70.56, 'temp_min': 71.37, 'temp_max': 71.37, 'pressure': 1012, 'humidity': 50, 'sea_level': 1012, 'grnd_level': 859}, 'visibility': 10000, 'wind': {'speed': 6.58, 'deg': 134, 'gust': 10.71}, 'clouds': {'all': 33}, 'dt': 1655872902, 'sys': {'country': 'TL', 'sunrise': 1655848330, 'sunset': 1655890096}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 49 of Set 1 | takoradi
# {'coord': {'lon': -1.7554, 'lat': 4.8845}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 73.74, 'feels_like': 75.18, 'temp_min': 73.74, 'temp_max': 73.74, 'pressure': 1013, 'humidity': 93, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 6.02, 'deg': 246, 'gust': 8.97}, 'rain': {'1h': 0.18}, 'clouds': {'all': 100}, 'dt': 1655872902, 'sys': {'country': 'GH', 'sunrise': 1655877409, 'sunset': 1655922065}, 'timezone': 0, 'id': 2294915, 'name': 'Takoradze', 'cod': 200}
# Processing Record 50 of Set 1 | hambantota
# {'coord': {'lon': 81.1185, 'lat': 6.1241}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 88.14, 'feels_like': 100.6, 'temp_min': 88.14, 'temp_max': 88.14, 'pressure': 1009, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 270}, 'clouds': {'all': 20}, 'dt': 1655872903, 'sys': {'type': 1, 'id': 9124, 'country': 'LK', 'sunrise': 1655857386, 'sunset': 1655902303}, 'timezone': 19800, 'id': 1244926, 'name': 'Hambantota', 'cod': 200}
# Processing Record 1 of Set 2 | berlevag
# {'coord': {'lon': 29.0864, 'lat': 70.8578}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 44.67, 'feels_like': 36.7, 'temp_min': 42.8, 'temp_max': 46.2, 'pressure': 1003, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 19.57, 'deg': 300}, 'clouds': {'all': 100}, 'dt': 1655872903, 'sys': {'type': 1, 'id': 1620, 'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 7200, 'id': 780687, 'name': 'Berlevåg', 'cod': 200}
# Processing Record 2 of Set 2 | talnakh
# {'coord': {'lon': 88.3972, 'lat': 69.4865}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 83.21, 'feels_like': 81.28, 'temp_min': 83.21, 'temp_max': 83.21, 'pressure': 1004, 'humidity': 29, 'sea_level': 1004, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 15.1, 'deg': 223, 'gust': 16.28}, 'clouds': {'all': 44}, 'dt': 1655872903, 'sys': {'type': 2, 'id': 49144, 'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# Processing Record 3 of Set 2 | chuy
# {'coord': {'lon': -53.4616, 'lat': -33.6971}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 52.56, 'feels_like': 51.46, 'temp_min': 52.56, 'temp_max': 52.56, 'pressure': 1016, 'humidity': 84, 'sea_level': 1016, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 14.81, 'deg': 174, 'gust': 27.18}, 'clouds': {'all': 97}, 'dt': 1655872904, 'sys': {'country': 'UY', 'sunrise': 1655894309, 'sunset': 1655929987}, 'timezone': -10800, 'id': 3443061, 'name': 'Chui', 'cod': 200}
# Processing Record 4 of Set 2 | attawapiskat
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 5 of Set 2 | khandyga
# {'coord': {'lon': 135.6, 'lat': 62.6667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.72, 'feels_like': 75.4, 'temp_min': 75.72, 'temp_max': 75.72, 'pressure': 1002, 'humidity': 51, 'sea_level': 1002, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 3.06, 'deg': 219, 'gust': 3.74}, 'clouds': {'all': 100}, 'dt': 1655872904, 'sys': {'country': 'RU', 'sunrise': 1655830567, 'sunset': 1655902967}, 'timezone': 32400, 'id': 2022773, 'name': 'Khandyga', 'cod': 200}
# Processing Record 6 of Set 2 | severo-kurilsk
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 49.91, 'feels_like': 45.88, 'temp_min': 49.91, 'temp_max': 49.91, 'pressure': 1014, 'humidity': 89, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 6952, 'wind': {'speed': 10.16, 'deg': 311, 'gust': 15.93}, 'clouds': {'all': 65}, 'dt': 1655872904, 'sys': {'country': 'RU', 'sunrise': 1655832162, 'sunset': 1655891518}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# Processing Record 7 of Set 2 | brae
# {'coord': {'lon': -1.353, 'lat': 60.3964}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 52.48, 'feels_like': 51.85, 'temp_min': 52.48, 'temp_max': 52.48, 'pressure': 1007, 'humidity': 94, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 19.53, 'deg': 220, 'gust': 30.91}, 'clouds': {'all': 100}, 'dt': 1655872905, 'sys': {'country': 'GB', 'sunrise': 1655865403, 'sunset': 1655933878}, 'timezone': 3600, 'id': 2654970, 'name': 'Brae', 'cod': 200}
# Processing Record 8 of Set 2 | hervey bay
# {'coord': {'lon': 152.8535, 'lat': -25.2986}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 72.01, 'feels_like': 71.31, 'temp_min': 72.01, 'temp_max': 72.01, 'pressure': 1018, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 219, 'gust': 24}, 'clouds': {'all': 2}, 'dt': 1655872905, 'sys': {'type': 2, 'id': 2032484, 'country': 'AU', 'sunrise': 1655843619, 'sunset': 1655881632}, 'timezone': 36000, 'id': 2146219, 'name': 'Hervey Bay', 'cod': 200}
# Processing Record 9 of Set 2 | matamba
# {'coord': {'lon': 33.9667, 'lat': -8.9833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 47.64, 'feels_like': 46.2, 'temp_min': 47.64, 'temp_max': 47.64, 'pressure': 1021, 'humidity': 66, 'sea_level': 1021, 'grnd_level': 797}, 'visibility': 10000, 'wind': {'speed': 3.94, 'deg': 176, 'gust': 5.35}, 'clouds': {'all': 2}, 'dt': 1655872905, 'sys': {'country': 'TZ', 'sunrise': 1655870285, 'sunset': 1655912039}, 'timezone': 10800, 'id': 154635, 'name': 'Matamba', 'cod': 200}
# Processing Record 10 of Set 2 | port blair
# {'coord': {'lon': 92.75, 'lat': 11.6667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 85.44, 'feels_like': 94.14, 'temp_min': 85.44, 'temp_max': 85.44, 'pressure': 1009, 'humidity': 71, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 11.83, 'deg': 200, 'gust': 13.18}, 'clouds': {'all': 100}, 'dt': 1655872906, 'sys': {'country': 'IN', 'sunrise': 1655853997, 'sunset': 1655900108}, 'timezone': 19800, 'id': 1259385, 'name': 'Port Blair', 'cod': 200}
# Processing Record 11 of Set 2 | georgetown
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.83, 'feels_like': 95.88, 'temp_min': 83.98, 'temp_max': 87.73, 'pressure': 1010, 'humidity': 79}, 'visibility': 7000, 'wind': {'speed': 6.91, 'deg': 200}, 'clouds': {'all': 20}, 'dt': 1655872906, 'sys': {'type': 2, 'id': 2037578, 'country': 'MY', 'sunrise': 1655852848, 'sunset': 1655897615}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# Processing Record 12 of Set 2 | thompson
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 60.96, 'feels_like': 58.82, 'temp_min': 60.96, 'temp_max': 60.96, 'pressure': 1009, 'humidity': 44}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 310}, 'clouds': {'all': 20}, 'dt': 1655872906, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1655804794, 'sunset': 1655867990}, 'timezone': -18000, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# Processing Record 13 of Set 2 | kenai
# {'coord': {'lon': -151.2583, 'lat': 60.5544}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 64.04, 'feels_like': 62.92, 'temp_min': 60.1, 'temp_max': 75.02, 'pressure': 1020, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1655872907, 'sys': {'type': 1, 'id': 7680, 'country': 'US', 'sunrise': 1655814856, 'sunset': 1655883565}, 'timezone': -28800, 'id': 5866063, 'name': 'Kenai', 'cod': 200}
# Processing Record 14 of Set 2 | hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 53.56, 'feels_like': 52.05, 'temp_min': 51.26, 'temp_max': 57.22, 'pressure': 1014, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 30}, 'clouds': {'all': 40}, 'dt': 1655872820, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1655847727, 'sunset': 1655880176}, 'timezone': 36000, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 15 of Set 2 | zhireken
# {'coord': {'lon': 117.3076, 'lat': 52.8249}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 70.05, 'feels_like': 68.83, 'temp_min': 70.05, 'temp_max': 70.05, 'pressure': 998, 'humidity': 44, 'sea_level': 998, 'grnd_level': 918}, 'visibility': 10000, 'wind': {'speed': 6.76, 'deg': 322, 'gust': 10.76}, 'clouds': {'all': 59}, 'dt': 1655872907, 'sys': {'country': 'RU', 'sunrise': 1655840746, 'sunset': 1655901569}, 'timezone': 32400, 'id': 2012510, 'name': 'Zhireken', 'cod': 200}
# Processing Record 16 of Set 2 | avarua
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.65, 'feels_like': 86.18, 'temp_min': 80.65, 'temp_max': 80.65, 'pressure': 1013, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 310}, 'clouds': {'all': 75}, 'dt': 1655872908, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1655831743, 'sunset': 1655870766}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# Processing Record 17 of Set 2 | hanmer springs
# {'coord': {'lon': 172.8167, 'lat': -42.5167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 39.38, 'feels_like': 36.5, 'temp_min': 39.38, 'temp_max': 39.38, 'pressure': 1028, 'humidity': 77, 'sea_level': 1028, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 348, 'gust': 3.06}, 'clouds': {'all': 0}, 'dt': 1655872908, 'sys': {'country': 'NZ', 'sunrise': 1655841536, 'sunset': 1655874132}, 'timezone': 43200, 'id': 2190299, 'name': 'Hanmer Springs', 'cod': 200}
# Processing Record 18 of Set 2 | kaeo
# {'coord': {'lon': 173.7833, 'lat': -35.1}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 56.32, 'feels_like': 55.08, 'temp_min': 56.32, 'temp_max': 56.32, 'pressure': 1024, 'humidity': 73, 'sea_level': 1024, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 132, 'gust': 3.27}, 'clouds': {'all': 59}, 'dt': 1655872908, 'sys': {'type': 2, 'id': 2012217, 'country': 'NZ', 'sunrise': 1655839982, 'sunset': 1655875222}, 'timezone': 43200, 'id': 2189343, 'name': 'Kaeo', 'cod': 200}
# Processing Record 19 of Set 2 | zhemchuzhnyy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 20 of Set 2 | manhattan beach
# {'coord': {'lon': -118.4109, 'lat': 33.8847}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 65.93, 'feels_like': 66.22, 'temp_min': 61.56, 'temp_max': 79.7, 'pressure': 1014, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 270}, 'clouds': {'all': 20}, 'dt': 1655872909, 'sys': {'type': 2, 'id': 2031920, 'country': 'US', 'sunrise': 1655815389, 'sunset': 1655867263}, 'timezone': -25200, 'id': 5370082, 'name': 'Manhattan Beach', 'cod': 200}
# Processing Record 21 of Set 2 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.3, 'feels_like': 72.34, 'temp_min': 65.95, 'temp_max': 78.39, 'pressure': 1016, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 210}, 'clouds': {'all': 0}, 'dt': 1655872701, 'sys': {'type': 2, 'id': 2008933, 'country': 'US', 'sunrise': 1655890881, 'sunset': 1655945788}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 22 of Set 2 | fort saint john
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 23 of Set 2 | narsaq
# {'coord': {'lon': -46.05, 'lat': 60.9167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 41.22, 'feels_like': 41.22, 'temp_min': 41.22, 'temp_max': 41.22, 'pressure': 1007, 'humidity': 79, 'sea_level': 1007, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 2.75, 'deg': 74, 'gust': 6.51}, 'clouds': {'all': 0}, 'dt': 1655872909, 'sys': {'type': 1, 'id': 47, 'country': 'GL', 'sunrise': 1655875742, 'sunset': 1655944996}, 'timezone': -7200, 'id': 3421719, 'name': 'Narsaq', 'cod': 200}
# Processing Record 24 of Set 2 | torbay
# {'coord': {'lon': -52.7314, 'lat': 47.6666}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.47, 'feels_like': 57.38, 'temp_min': 46.53, 'temp_max': 59.88, 'pressure': 1022, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 270}, 'clouds': {'all': 100}, 'dt': 1655872910, 'sys': {'type': 1, 'id': 998, 'country': 'CA', 'sunrise': 1655883184, 'sunset': 1655940762}, 'timezone': -9000, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# Processing Record 25 of Set 2 | camacha
# {'coord': {'lon': -16.3333, 'lat': 33.0833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 62.02, 'feels_like': 61.3, 'temp_min': 62.02, 'temp_max': 62.02, 'pressure': 1019, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 350}, 'clouds': {'all': 75}, 'dt': 1655872910, 'sys': {'type': 1, 'id': 6902, 'country': 'PT', 'sunrise': 1655877428, 'sunset': 1655929044}, 'timezone': 3600, 'id': 2270385, 'name': 'Camacha', 'cod': 200}
# Processing Record 26 of Set 2 | mandalgovi
# {'coord': {'lon': 106.2708, 'lat': 45.7625}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.18, 'feels_like': 79.99, 'temp_min': 82.18, 'temp_max': 82.18, 'pressure': 1000, 'humidity': 20, 'sea_level': 1000, 'grnd_level': 853}, 'visibility': 10000, 'wind': {'speed': 11.88, 'deg': 307, 'gust': 16.64}, 'clouds': {'all': 70}, 'dt': 1655872910, 'sys': {'country': 'MN', 'sunrise': 1655845512, 'sunset': 1655902102}, 'timezone': 28800, 'id': 2030065, 'name': 'Mandalgovi', 'cod': 200}
# Processing Record 27 of Set 2 | debre zeyit
# {'coord': {'lon': 38.9833, 'lat': 8.75}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 65.77, 'feels_like': 64.81, 'temp_min': 65.77, 'temp_max': 65.77, 'pressure': 1015, 'humidity': 59, 'sea_level': 1015, 'grnd_level': 814}, 'visibility': 10000, 'wind': {'speed': 4.97, 'deg': 250, 'gust': 7.05}, 'clouds': {'all': 77}, 'dt': 1655872911, 'sys': {'country': 'ET', 'sunrise': 1655867220, 'sunset': 1655912697}, 'timezone': 10800, 'id': 339666, 'name': 'Bishoftu', 'cod': 200}
# Processing Record 28 of Set 2 | aljezur
# {'coord': {'lon': -8.8033, 'lat': 37.3191}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 60.91, 'feels_like': 60.98, 'temp_min': 60.91, 'temp_max': 60.91, 'pressure': 1014, 'humidity': 91, 'sea_level': 1014, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 5.84, 'deg': 302, 'gust': 9.62}, 'clouds': {'all': 39}, 'dt': 1655872911, 'sys': {'country': 'PT', 'sunrise': 1655874907, 'sunset': 1655927951}, 'timezone': 3600, 'id': 2271968, 'name': 'Aljezur', 'cod': 200}
# Processing Record 29 of Set 2 | tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 35.76, 'feels_like': 35.76, 'temp_min': 35.76, 'temp_max': 35.76, 'pressure': 1000, 'humidity': 91, 'sea_level': 1000, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 179, 'gust': 3.24}, 'clouds': {'all': 75}, 'dt': 1655872911, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1655866583, 'sunset': 1655950116}, 'timezone': -7200, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Processing Record 30 of Set 2 | chokurdakh
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 52.59, 'feels_like': 50.76, 'temp_min': 52.59, 'temp_max': 52.59, 'pressure': 999, 'humidity': 68, 'sea_level': 999, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 9.71, 'deg': 205, 'gust': 19.28}, 'rain': {'1h': 0.72}, 'clouds': {'all': 100}, 'dt': 1655872912, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 31 of Set 2 | ruza
# {'coord': {'lon': 36.1952, 'lat': 55.699}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.87, 'feels_like': 51.22, 'temp_min': 51.87, 'temp_max': 51.87, 'pressure': 1002, 'humidity': 95, 'sea_level': 1002, 'grnd_level': 980}, 'visibility': 10000, 'wind': {'speed': 7.18, 'deg': 38, 'gust': 19.19}, 'clouds': {'all': 100}, 'dt': 1655872912, 'sys': {'country': 'RU', 'sunrise': 1655859050, 'sunset': 1655922204}, 'timezone': 10800, 'id': 500303, 'name': 'Ruza', 'cod': 200}
# Processing Record 32 of Set 2 | beringovskiy
# {'coord': {'lon': 179.3167, 'lat': 63.05}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 50.16, 'feels_like': 48.45, 'temp_min': 50.16, 'temp_max': 50.16, 'pressure': 1011, 'humidity': 76, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 10.31, 'deg': 243, 'gust': 12.1}, 'rain': {'1h': 0.12}, 'clouds': {'all': 99}, 'dt': 1655872912, 'sys': {'country': 'RU', 'sunrise': 1655819656, 'sunset': 1655892891}, 'timezone': 43200, 'id': 2126710, 'name': 'Beringovskiy', 'cod': 200}
# Processing Record 33 of Set 2 | bambous virieux
# {'coord': {'lon': 57.7575, 'lat': -20.3428}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 68.25, 'feels_like': 68.4, 'temp_min': 68.25, 'temp_max': 71.22, 'pressure': 1018, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1655872913, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1655865837, 'sunset': 1655905066}, 'timezone': 14400, 'id': 1106677, 'name': 'Bambous Virieux', 'cod': 200}
# Processing Record 34 of Set 2 | komsomolskiy
# {'coord': {'lon': 71.7189, 'lat': 40.4272}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.72, 'feels_like': 76.98, 'temp_min': 77.72, 'temp_max': 77.72, 'pressure': 1005, 'humidity': 38}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 330}, 'clouds': {'all': 99}, 'dt': 1655872913, 'sys': {'type': 1, 'id': 9014, 'country': 'UZ', 'sunrise': 1655854990, 'sunset': 1655909211}, 'timezone': 18000, 'id': 1513491, 'name': 'Yangi Marg`ilon', 'cod': 200}
# Processing Record 35 of Set 2 | constitucion
# {'coord': {'lon': -72.4167, 'lat': -35.3333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 50.13, 'feels_like': 48.74, 'temp_min': 50.13, 'temp_max': 50.13, 'pressure': 1012, 'humidity': 83, 'sea_level': 1012, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 7.63, 'deg': 92, 'gust': 10.78}, 'clouds': {'all': 97}, 'dt': 1655872913, 'sys': {'country': 'CL', 'sunrise': 1655899114, 'sunset': 1655934281}, 'timezone': -14400, 'id': 3893726, 'name': 'Constitución', 'cod': 200}
# Processing Record 36 of Set 2 | namibe
# {'coord': {'lon': 12.1522, 'lat': -15.1961}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 59.34, 'feels_like': 57.94, 'temp_min': 59.34, 'temp_max': 59.34, 'pressure': 1013, 'humidity': 63, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 4.65, 'deg': 207, 'gust': 4.63}, 'clouds': {'all': 0}, 'dt': 1655872914, 'sys': {'country': 'AO', 'sunrise': 1655876195, 'sunset': 1655916602}, 'timezone': 3600, 'id': 3347019, 'name': 'Mossamedes', 'cod': 200}
# Processing Record 37 of Set 2 | ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.2167}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 33.82, 'feels_like': 29.57, 'temp_min': 33.82, 'temp_max': 33.82, 'pressure': 1015, 'humidity': 93}, 'visibility': 6000, 'wind': {'speed': 4.61, 'deg': 170}, 'clouds': {'all': 100}, 'dt': 1655872914, 'sys': {'type': 1, 'id': 165, 'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -7200, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# Processing Record 38 of Set 2 | saint-philippe
# ...
# Processing Record 18 of Set 15 | thinadhoo
# {'coord': {'lon': 72.9333, 'lat': 0.5333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 90.91, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1010, 'humidity': 70, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 8.79, 'deg': 335, 'gust': 9.75}, 'clouds': {'all': 100}, 'dt': 1655873107, 'sys': {'country': 'MV', 'sunrise': 1655859936, 'sunset': 1655903682}, 'timezone': 18000, 'id': 1337610, 'name': 'Thinadhoo', 'cod': 200}
# Processing Record 19 of Set 15 | san francisco
# {'coord': {'lon': -122.4194, 'lat': 37.7749}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 74.46, 'feels_like': 73.96, 'temp_min': 64.42, 'temp_max': 89.47, 'pressure': 1010, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1655873045, 'sys': {'type': 2, 'id': 2016474, 'country': 'US', 'sunrise': 1655815683, 'sunset': 1655868893}, 'timezone': -25200, 'id': 5391959, 'name': 'San Francisco', 'cod': 200}
# Processing Record 20 of Set 15 | kambove
# {'coord': {'lon': 26.5969, 'lat': -10.8764}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 48.04, 'feels_like': 46.26, 'temp_min': 48.04, 'temp_max': 48.04, 'pressure': 1020, 'humidity': 72, 'sea_level': 1020, 'grnd_level': 865}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 148, 'gust': 17.56}, 'clouds': {'all': 0}, 'dt': 1655873108, 'sys': {'country': 'CD', 'sunrise': 1655872256, 'sunset': 1655913606}, 'timezone': 7200, 'id': 923058, 'name': 'Kambove', 'cod': 200}
# Processing Record 21 of Set 15 | dalvik
# {'coord': {'lon': -18.5286, 'lat': 65.9702}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 48.13, 'feels_like': 42.78, 'temp_min': 48.13, 'temp_max': 48.13, 'pressure': 987, 'humidity': 73, 'sea_level': 987, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 12.97, 'deg': 249, 'gust': 20.45}, 'clouds': {'all': 80}, 'dt': 1655873108, 'sys': {'type': 1, 'id': 83, 'country': 'IS', 'sunrise': 0, 'sunset': 0}, 'timezone': 0, 'id': 2632287, 'name': 'Dalvik', 'cod': 200}
# Processing Record 22 of Set 15 | fuyu
# {'coord': {'lon': 124.8167, 'lat': 45.1833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 85.33, 'feels_like': 85.5, 'temp_min': 85.33, 'temp_max': 85.33, 'pressure': 1001, 'humidity': 44, 'sea_level': 1001, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 15.52, 'deg': 213, 'gust': 17.43}, 'clouds': {'all': 100}, 'dt': 1655873109, 'sys': {'country': 'CN', 'sunrise': 1655841202, 'sunset': 1655897509}, 'timezone': 28800, 'id': 2037335, 'name': 'Fuyu', 'cod': 200}
# Processing Record 23 of Set 15 | kattivakkam
# {'coord': {'lon': 80.3167, 'lat': 13.2167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 85.06, 'feels_like': 97.66, 'temp_min': 85.06, 'temp_max': 86.09, 'pressure': 1006, 'humidity': 84, 'sea_level': 1006, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 11.05, 'deg': 243, 'gust': 13.91}, 'clouds': {'all': 95}, 'dt': 1655873109, 'sys': {'type': 2, 'id': 2012809, 'country': 'IN', 'sunrise': 1655856810, 'sunset': 1655903264}, 'timezone': 19800, 'id': 1267433, 'name': 'Kattivākkam', 'cod': 200}
# Processing Record 24 of Set 15 | piacabucu
# {'coord': {'lon': -36.4344, 'lat': -10.4056}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 74.23, 'feels_like': 75.34, 'temp_min': 74.23, 'temp_max': 74.23, 'pressure': 1015, 'humidity': 85, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 122, 'gust': 12.41}, 'clouds': {'all': 28}, 'dt': 1655873110, 'sys': {'country': 'BR', 'sunrise': 1655887335, 'sunset': 1655928786}, 'timezone': -10800, 'id': 3454005, 'name': 'Piaçabuçu', 'cod': 200}
# Processing Record 25 of Set 15 | zhuhai
# {'coord': {'lon': 113.5678, 'lat': 22.2769}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 85.41, 'feels_like': 98.01, 'temp_min': 83.91, 'temp_max': 94.86, 'pressure': 1009, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 180}, 'clouds': {'all': 20}, 'dt': 1655873112, 'sys': {'type': 1, 'id': 9204, 'country': 'CN', 'sunrise': 1655847761, 'sunset': 1655896350}, 'timezone': 28800, 'id': 1790437, 'name': 'Zhuhai', 'cod': 200}
# Processing Record 26 of Set 15 | port shepstone
# {'coord': {'lon': 30.455, 'lat': -30.7414}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 61.32, 'feels_like': 61.2, 'temp_min': 61.32, 'temp_max': 61.32, 'pressure': 1026, 'humidity': 86, 'sea_level': 1026, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 9.66, 'deg': 4, 'gust': 18.75}, 'clouds': {'all': 42}, 'dt': 1655873112, 'sys': {'country': 'ZA', 'sunrise': 1655873730, 'sunset': 1655910280}, 'timezone': 7200, 'id': 964406, 'name': 'Port Shepstone', 'cod': 200}
# Processing Record 27 of Set 15 | changji
# {'coord': {'lon': 87.3167, 'lat': 44.0167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 95.79, 'feels_like': 91.42, 'temp_min': 95.79, 'temp_max': 95.79, 'pressure': 1008, 'humidity': 15}, 'visibility': 10000, 'wind': {'speed': 6.71, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1655873112, 'sys': {'type': 1, 'id': 9677, 'country': 'CN', 'sunrise': 1655850478, 'sunset': 1655906235}, 'timezone': 28800, 'id': 1529569, 'name': 'Changji', 'cod': 200}
# Processing Record 28 of Set 15 | sangar
# {'coord': {'lon': 127.4739, 'lat': 63.9242}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 75.25, 'feels_like': 73.98, 'temp_min': 75.25, 'temp_max': 75.25, 'pressure': 1003, 'humidity': 32, 'sea_level': 1003, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 11.07, 'deg': 304, 'gust': 14.92}, 'clouds': {'all': 23}, 'dt': 1655873113, 'sys': {'country': 'RU', 'sunrise': 1655830989, 'sunset': 1655906446}, 'timezone': 32400, 'id': 2017215, 'name': 'Sangar', 'cod': 200}
# Processing Record 29 of Set 15 | murud
# {'coord': {'lon': 72.965, 'lat': 18.3258}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.65, 'feels_like': 79.25, 'temp_min': 77.65, 'temp_max': 77.65, 'pressure': 1006, 'humidity': 88, 'sea_level': 1006, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 6.08, 'deg': 142, 'gust': 7.92}, 'clouds': {'all': 100}, 'dt': 1655873113, 'sys': {'country': 'IN', 'sunrise': 1655857988, 'sunset': 1655905614}, 'timezone': 19800, 'id': 1262403, 'name': 'Murud', 'cod': 200}
# Processing Record 30 of Set 15 | manta
# {'coord': {'lon': -80.7333, 'lat': -0.95}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.38, 'feels_like': 72.36, 'temp_min': 71.38, 'temp_max': 71.38, 'pressure': 1013, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 200}, 'clouds': {'all': 100}, 'dt': 1655873113, 'sys': {'type': 1, 'id': 8552, 'country': 'EC', 'sunrise': 1655810564, 'sunset': 1655854000}, 'timezone': -18000, 'id': 3654410, 'name': 'Manta', 'cod': 200}
# Processing Record 31 of Set 15 | coro
# {'coord': {'lon': -69.6734, 'lat': 11.4045}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.72, 'feels_like': 79.23, 'temp_min': 77.72, 'temp_max': 77.72, 'pressure': 1011, 'humidity': 86, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 13.44, 'deg': 100, 'gust': 20.51}, 'clouds': {'all': 100}, 'dt': 1655873114, 'sys': {'country': 'VE', 'sunrise': 1655893013, 'sunset': 1655939066}, 'timezone': -14400, 'id': 3645213, 'name': 'Coro', 'cod': 200}
# Processing Record 32 of Set 15 | arcata
# {'coord': {'lon': -124.0828, 'lat': 40.8665}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 58.68, 'feels_like': 58.01, 'temp_min': 56.59, 'temp_max': 67.68, 'pressure': 1014, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 110}, 'clouds': {'all': 0}, 'dt': 1655873114, 'sys': {'type': 2, 'id': 2010265, 'country': 'US', 'sunrise': 1655815488, 'sunset': 1655869886}, 'timezone': -25200, 'id': 5558953, 'name': 'Arcata', 'cod': 200}
# Processing Record 33 of Set 15 | susanville
# {'coord': {'lon': -120.653, 'lat': 40.4163}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 63.66, 'feels_like': 61.23, 'temp_min': 61.81, 'temp_max': 66.04, 'pressure': 1021, 'humidity': 32}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 280}, 'clouds': {'all': 0}, 'dt': 1655873114, 'sys': {'type': 2, 'id': 2044236, 'country': 'US', 'sunrise': 1655814756, 'sunset': 1655868972}, 'timezone': -25200, 'id': 5572400, 'name': 'Susanville', 'cod': 200}
# Processing Record 34 of Set 15 | new philadelphia
# {'coord': {'lon': -81.4457, 'lat': 40.4898}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 73, 'feels_like': 73.72, 'temp_min': 67.84, 'temp_max': 74.8, 'pressure': 1017, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 141, 'gust': 5.01}, 'clouds': {'all': 0}, 'dt': 1655873115, 'sys': {'type': 2, 'id': 2005596, 'country': 'US', 'sunrise': 1655891743, 'sunset': 1655945987}, 'timezone': -14400, 'id': 5164390, 'name': 'New Philadelphia', 'cod': 200}
# Processing Record 35 of Set 15 | anito
# {'coord': {'lon': 125.2886, 'lat': 12.4497}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 85.98, 'feels_like': 94.59, 'temp_min': 85.98, 'temp_max': 85.98, 'pressure': 1010, 'humidity': 69, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 6.67, 'deg': 69, 'gust': 7.43}, 'rain': {'1h': 0.65}, 'clouds': {'all': 96}, 'dt': 1655873115, 'sys': {'country': 'PH', 'sunrise': 1655846100, 'sunset': 1655892384}, 'timezone': 28800, 'id': 1730622, 'name': 'Anito', 'cod': 200}
# Processing Record 36 of Set 15 | san policarpo
# {'coord': {'lon': 125.5072, 'lat': 12.1791}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 85.39, 'feels_like': 93.2, 'temp_min': 85.39, 'temp_max': 85.39, 'pressure': 1010, 'humidity': 69, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.82, 'deg': 70, 'gust': 6.87}, 'rain': {'1h': 0.65}, 'clouds': {'all': 88}, 'dt': 1655873115, 'sys': {'country': 'PH', 'sunrise': 1655846078, 'sunset': 1655892301}, 'timezone': 28800, 'id': 1688696, 'name': 'San Policarpo', 'cod': 200}
# Processing Record 37 of Set 15 | fukue
# {'coord': {'lon': 128.8419, 'lat': 32.6881}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.16, 'feels_like': 79.16, 'temp_min': 79.16, 'temp_max': 79.16, 'pressure': 1010, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 190}, 'clouds': {'all': 40}, 'dt': 1655873116, 'sys': {'type': 1, 'id': 7986, 'country': 'JP', 'sunrise': 1655842643, 'sunset': 1655894135}, 'timezone': 32400, 'id': 1863997, 'name': 'Fukuechō', 'cod': 200}
# Processing Record 38 of Set 15 | vallenar
# {'coord': {'lon': -70.7581, 'lat': -28.5708}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 48.04, 'feels_like': 45.3, 'temp_min': 48.04, 'temp_max': 48.04, 'pressure': 1015, 'humidity': 90, 'sea_level': 1015, 'grnd_level': 963}, 'visibility': 10000, 'wind': {'speed': 6.04, 'deg': 16, 'gust': 9.01}, 'clouds': {'all': 87}, 'dt': 1655873116, 'sys': {'country': 'CL', 'sunrise': 1655897723, 'sunset': 1655934877}, 'timezone': -14400, 'id': 3868633, 'name': 'Vallenar', 'cod': 200}
# Processing Record 39 of Set 15 | scarborough
# {'coord': {'lon': -0.4044, 'lat': 54.2797}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 56.43, 'feels_like': 55.9, 'temp_min': 54.93, 'temp_max': 58.33, 'pressure': 1014, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 2.73, 'deg': 248, 'gust': 3.04}, 'clouds': {'all': 30}, 'dt': 1655872995, 'sys': {'type': 2, 'id': 2005986, 'country': 'GB', 'sunrise': 1655868442, 'sunset': 1655930383}, 'timezone': 3600, 'id': 2638419, 'name': 'Scarborough', 'cod': 200}
# Processing Record 40 of Set 15 | tanda
# {'coord': {'lon': 82.65, 'lat': 26.55}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 98.49, 'feels_like': 103.24, 'temp_min': 98.49, 'temp_max': 98.49, 'pressure': 1003, 'humidity': 36, 'sea_level': 1003, 'grnd_level': 993}, 'visibility': 10000, 'wind': {'speed': 7.78, 'deg': 94, 'gust': 5.88}, 'clouds': {'all': 2}, 'dt': 1655873117, 'sys': {'country': 'IN', 'sunrise': 1655854625, 'sunset': 1655904329}, 'timezone': 19800, 'id': 1255024, 'name': 'Tāndā', 'cod': 200}
# Processing Record 41 of Set 15 | hays
# {'coord': {'lon': -98.0336, 'lat': 30.0502}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 81.97, 'feels_like': 85.75, 'temp_min': 79.34, 'temp_max': 84.6, 'pressure': 1022, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 172, 'gust': 5.01}, 'clouds': {'all': 37}, 'dt': 1655873117, 'sys': {'type': 2, 'id': 2010474, 'country': 'US', 'sunrise': 1655811088, 'sunset': 1655861781}, 'timezone': -18000, 'id': 4696788, 'name': 'Hays', 'cod': 200}
# Processing Record 42 of Set 15 | belmonte
# {'coord': {'lon': -38.8828, 'lat': -15.8631}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 70.72, 'feels_like': 71.35, 'temp_min': 70.72, 'temp_max': 70.72, 'pressure': 1018, 'humidity': 82, 'sea_level': 1018, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 3.71, 'deg': 167, 'gust': 5.46}, 'clouds': {'all': 36}, 'dt': 1655873117, 'sys': {'country': 'BR', 'sunrise': 1655888520, 'sunset': 1655928778}, 'timezone': -10800, 'id': 3470137, 'name': 'Belmonte', 'cod': 200}
# Processing Record 43 of Set 15 | acari
# {'coord': {'lon': -74.6158, 'lat': -15.4311}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 61.9, 'feels_like': 61.27, 'temp_min': 61.9, 'temp_max': 61.9, 'pressure': 1015, 'humidity': 74, 'sea_level': 1015, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 1.83, 'deg': 172, 'gust': 2.62}, 'clouds': {'all': 68}, 'dt': 1655873118, 'sys': {'country': 'PE', 'sunrise': 1655810637, 'sunset': 1655850991}, 'timezone': -18000, 'id': 3948613, 'name': 'Acarí', 'cod': 200}
# -----------------------------
# Weather Data Complete
# -----------------------------

# %%
# Convert data to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(25)
# Out:
#                City      Lat       Lng Current Description  Max Temp  \
# 0         Kununurra -15.7667  128.7333           clear sky     87.78
# 1            Kampot  10.6167  104.1833     overcast clouds     86.05
# 2     San Cristobal   7.7669  -72.2250       broken clouds     68.18
# 3          San Jose  37.3394 -121.8950           clear sky     90.68
# 4           Cozumel  20.5083  -86.9458       broken clouds     75.94
# 5           Mataura -46.1927  168.8643           clear sky     46.47
# 6        Butaritari   3.0707  172.7902       broken clouds     82.94
# 7       Port Alfred -33.5906   26.8910     overcast clouds     65.03
# 8            Atuona  -9.8000 -139.0333          light rain     77.65
# 9           Sorland  67.6670   12.6934     overcast clouds     46.26
# 10          Rikitea -23.1203 -134.9692    scattered clouds     73.31
# 11       Bredasdorp -34.5322   20.0403     overcast clouds     55.94
# 12          Methoni  36.8197   21.7049           clear sky     71.46
# 13         Luderitz -26.6481   15.1594           clear sky     52.68
# 14       Zhezkazgan  47.8043   67.7144           clear sky     80.58
# 15        Cape Town -33.9258   18.4232           clear sky     57.11
# 16          Ushuaia -54.8000  -68.3000          few clouds     37.06
# 17      New Norfolk -42.7826  147.0587    scattered clouds     56.88
# 18         Hermanus -34.4187   19.2345     overcast clouds     57.79
# 19        Busselton -33.6500  115.3333    scattered clouds     66.90
# 20  Plettenberg Bay -34.0527   23.3716     overcast clouds     59.56
# 21             Jalu  29.0331   21.5482           clear sky     77.59
# 22      Yellowknife  62.4560 -114.3525    scattered clouds     64.92
# 23           Albany  42.6001  -73.9662     overcast clouds     61.30
# 24     Puerto Ayora  -0.7393  -90.3518    scattered clouds     69.55
#
#     Humidity  Cloudiness  Wind Speed Country
# 0         20           4       13.80      AU
# 1         57          86        6.42      KH
# 2         98          54        3.15      VE
# 3         33           0       11.50      US
# 4         94          64       10.69      MX
# 5         87           1        1.19      NZ
# 6         70          68       12.88      KI
# 7         82         100       18.90      ZA
# 8         81          14       24.54      PF
# 9         63         100        3.09      NO
# 10        65          36        8.41      PF
# 11        96         100        4.56      ZA
# 12        68           0       11.03      GR
# 13        74           1        4.76      NA
# 14        22           0        8.95      KZ
# 15        91           0        4.61      ZA
# 16        75          20       26.46      AR
# 17        80          39        1.52      AU
# 18        81         100        7.29      ZA
# 19        64          50       15.64      AU
# 20        68          99        1.36      ZA
# 21        36           0        6.33      LY
# 22        52          40        3.44      CA
# 23        92         100        1.99      US
# 24        95          42        1.01      EC

# %%
# Reorder columns
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
df = city_data_df[new_order]
df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kununurra      AU -15.7667  128.7333     87.78        20           4
# 1         Kampot      KH  10.6167  104.1833     86.05        57          86
# 2  San Cristobal      VE   7.7669  -72.2250     68.18        98          54
# 3       San Jose      US  37.3394 -121.8950     90.68        33           0
# 4        Cozumel      MX  20.5083  -86.9458     75.94        94          64
# 5        Mataura      NZ -46.1927  168.8643     46.47        87           1
# 6     Butaritari      KI   3.0707  172.7902     82.94        70          68
# 7    Port Alfred      ZA -33.5906   26.8910     65.03        82         100
# 8         Atuona      PF  -9.8000 -139.0333     77.65        81          14
# 9        Sorland      NO  67.6670   12.6934     46.26        63         100
#
#    Wind Speed Current Description
# 0       13.80           clear sky
# 1        6.42     overcast clouds
# 2        3.15       broken clouds
# 3       11.50           clear sky
# 4       10.69       broken clouds
# 5        1.19           clear sky
# 6       12.88       broken clouds
# 7       18.90     overcast clouds
# 8       24.54          light rain
# 9        3.09     overcast clouds

# %%
# Output to a database
weather_file = "WeatherPy_Database.csv"
df.to_csv(weather_file, index_label="City_ID")

# %%
print("File created")
# Out:
# File created
